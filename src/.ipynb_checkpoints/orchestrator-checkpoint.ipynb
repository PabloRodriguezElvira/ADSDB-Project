# %% [markdown]
# # Orchestrator Notebook
# This notebook runs all the pipeline processes in sequence.

# %% [markdown]
# ## Project root & sys.path setup
#
# This section ensures the notebook runs modules like `python -m src...` by setting CWD and sys.path.

# %%
import os, sys, pathlib

# Compute the project root by going one level up from the notebook's folder
ROOT = pathlib.Path(os.getcwd()).resolve().parents[0]  # assumes notebook is in /src/

# Change current working directory to the project root
os.chdir(ROOT)

# Add the project root to sys.path (so 'import src.*' works)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("CWD:", os.getcwd())
print("sys.executable:", sys.executable)
# Out:
# CWD: /home/paloli/Documentos/MDS/ADSDB/ADSDB-Project
# sys.executable: /home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/bin/python3.13

# %% [markdown]
# ## Configuration and modules definition
#
# Defines each module in order to be executed. The order is the following:
# 1. MinIO and ChromaDB managers
# 2. Data ingestion
# 3. Landing zone
# 4. Formatted zone
# 5. Trusted zone
# 6. Exploitation zone

# %%
# --- Configuration ---
from pathlib import Path
import os


MODULES = [
    # --------- Managers ---------
    {
        "name": "MinIO manager",
        "module": "src.common.minio_manager",  
        "args": []
    },
    {
        "name": "ChromaDB manager",
        "module": "src.common.chroma_client", 
        "args": []
    },

    # --------- Data ingestion ---------
    {
        "name": "Text ingestion",
        "module": "src.data_management.data_ingestion.text_ingestion",
        "args": []
    },
    {
        "name": "Image ingestion",
        "module": "src.data_management.data_ingestion.image_ingestion",
        "args": []
    },
    {
        "name": "Video ingestion",
        "module": "src.data_management.data_ingestion.video_ingestion",
        "args": []
    },

    # --------- Landing zone --------- 
    # {
    #     "name": "Landing zone",
    #     "module": "src.data_management.landing_zone.landing_zone",
    #     "args": []
    # },


    # # --------- Formatted zone --------- 
    # {
    #     "name": "Formatted text",
    #     "module": "src.data_management.formatted_zone.formatted_text",
    #     "args": []
    # },
    # {
    #     "name": "Formatted images",
    #     "module": "src.data_management.formatted_zone.formatted_images",
    #     "args": []
    # },
    # {
    #     "name": "Formatted videos",
    #     "module": "src.data_management.formatted_zone.formatted_videos",
    #     "args": []
    # },


    # # --------- Trusted zone --------- 
    # {
    #     "name": "Trusted text",
    #     "module": "src.data_management.trusted_zone.trusted_text",
    #     "args": []
    # },
    # {
    #     "name": "Trusted images",
    #     "module": "src.data_management.trusted_zone.trusted_images",
    #     "args": []
    # }    
]

# %%
# --- Helpers to run modules ---
import subprocess, sys, shlex, time

def run_module(module: str, args=None, env=None, check=True, timeout=None, cwd=None):
    """
    Run a Python module with `python -m <module> [args...]` and stream output
    """

    if args is None: args = []
    cmd = [sys.executable, "-u", "-m", module, *map(str, args)]
    print("\n$", " ".join(shlex.quote(c) for c in cmd)) # shows command to be executed in console

    env2 = os.environ.copy()
    if env: env2.update(env)

    start = time.time()
    rc = subprocess.run(cmd, env=env2, cwd=cwd, check=False, timeout=timeout).returncode
    if check and rc != 0:
        raise subprocess.CalledProcessError(rc, cmd)
    print(f"[done in {time.time()-start:.1f}s]")
    return rc
    # Stream to notebook and optional log file
    # with (open(log_file, "a", encoding="utf-8") if log_file else open(os.devnull, "w")) as lf:
    #     for line in proc.stdout:
    #         print(line, end="")
    #         if log_file:
    #             lf.write(line)
    #     ret = proc.wait(timeout=timeout)
    #     duration = time.time() - start
    #     print(f"\n[INFO] Module finished with code {ret} in {duration:.1f}s")
    #     if log_file:
    #         lf.write(f"\n[INFO] Module finished with code {ret} in {duration:.1f}s\n")
    # if check and ret != 0:
    #     raise RuntimeError(f"Module {module} exited with code {ret}")
    # return ret

# %%
# --- Run pipeline ---
from datetime import datetime

print("=== Pipeline start:", datetime.now().isoformat(), "===")

for step in MODULES:
    print(f"\n=== Step: {step['name']} ===")
    run_module(
        module = step["module"],
        args = step.get("args", []),
        check = True,
        timeout = None
    )
print("\n=== Pipeline completed successfully ===")
# Out:
# === Pipeline start: 2025-10-13T12:31:11.141537 ===
#
# === Step: MinIO manager ===
#
# $ /home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/bin/python3.13 -u -m src.common.minio_manager
# [OK]: landing-zone/temporal_landing/
# [OK]: landing-zone/persistent_landing/image_data/
# [OK]: landing-zone/persistent_landing/video_data/
# [OK]: landing-zone/persistent_landing/text_data/
# [OK]: formatted-zone/formatted/image_data/
# [OK]: formatted-zone/formatted/video_data/
# [OK]: formatted-zone/formatted/text_data/
# [OK]: trusted-zone/trusted/image_data/
# [OK]: trusted-zone/trusted/video_data/
# [OK]: trusted-zone/trusted/text_data/
# [OK]: rejected-zone/rejected/image_data/
# [OK]: rejected-zone/rejected/video_data/
# [OK]: rejected-zone/rejected/text_data/
# [done in 0.6s]
#
# === Step: ChromaDB manager ===
#
# $ /home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/bin/python3.13 -u -m src.common.chroma_client
# [done in 3.9s]
#
# === Step: Text ingestion ===
#
# $ /home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/bin/python3.13 -u -m src.data_management.data_ingestion.text_ingestion
# [OK] Uploaded /home/paloli/.cache/kagglehub/datasets/hugodarwood/epirecipes/versions/2/full_format_recipes.json to s3://landing-zone/temporal_landing/full_format_recipes.json
# [done in 3.9s]
#
# === Step: Image ingestion ===
#
# $ /home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/bin/python3.13 -u -m src.data_management.data_ingestion.image_ingestion
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/0.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-0.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/1.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-1.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/10.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-2.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/100.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-3.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/101.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-4.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/102.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-5.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/103.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-6.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/104.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-7.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/105.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-8.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/106.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-9.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/107.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-10.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/108.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-11.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/109.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-12.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/11.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-13.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/110.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-14.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/111.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-15.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/112.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-16.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/113.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-17.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/114.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-18.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/115.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-19.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/116.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-20.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/117.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-21.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/118.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-22.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/119.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-23.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/12.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-24.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/120.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-25.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/121.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-26.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/122.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-27.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/123.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-28.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/124.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-29.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/125.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-30.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/126.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-31.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/127.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-32.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/128.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-33.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/129.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-34.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/13.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-35.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/130.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-36.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/131.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-37.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/132.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-38.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/133.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-39.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/134.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-40.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/135.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-41.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/136.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-42.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/137.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-43.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/138.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-44.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/139.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-45.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/14.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-46.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/140.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-47.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/141.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-48.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/142.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-49.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/143.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-50.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/144.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-51.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/145.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-52.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/146.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-53.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/147.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-54.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/148.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-55.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/149.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-56.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/15.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-57.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/150.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-58.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/151.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-59.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/152.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-60.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/153.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-61.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/154.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-62.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/155.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-63.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/156.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-64.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/157.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-65.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/158.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-66.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/159.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-67.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/16.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-68.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/160.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-69.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/161.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-70.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/162.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-71.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/163.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-72.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/164.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-73.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/165.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-74.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/166.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-75.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/167.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-76.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/168.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-77.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/169.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-78.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/17.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-79.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/170.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-80.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/171.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-81.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/172.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-82.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/173.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-83.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/174.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-84.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/175.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-85.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/176.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-86.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/177.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-87.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/178.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-88.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/179.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-89.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/18.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-90.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/180.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-91.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/181.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-92.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/182.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-93.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/183.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-94.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/184.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-95.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/185.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-96.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/186.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-97.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/187.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-98.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/188.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-99.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/189.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-100.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/19.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-101.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/190.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-102.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/191.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-103.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/192.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-104.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/193.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-105.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/194.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-106.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/195.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-107.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/196.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-108.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/197.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-109.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/198.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-110.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/199.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-111.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/2.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-112.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/20.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-113.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/200.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-114.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/201.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-115.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/202.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-116.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/203.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-117.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/204.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-118.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/205.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-119.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/206.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-120.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/207.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-121.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/208.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-122.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/209.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-123.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/21.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-124.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/210.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-125.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/211.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-126.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/212.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-127.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/213.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-128.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/214.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-129.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/215.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-130.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/216.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-131.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/217.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-132.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/218.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-133.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/219.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-134.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/22.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-135.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/220.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-136.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/221.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-137.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/222.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-138.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/223.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-139.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/224.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-140.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/225.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-141.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/226.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-142.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/227.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-143.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/228.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-144.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/229.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-145.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/23.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-146.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/230.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-147.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/231.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-148.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/232.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-149.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/233.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-150.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/234.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-151.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/235.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-152.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/236.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-153.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/237.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-154.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/238.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-155.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/239.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-156.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/24.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-157.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/240.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-158.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/241.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-159.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/242.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-160.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/243.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-161.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/244.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-162.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/245.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-163.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/246.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-164.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/247.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-165.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/248.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-166.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/249.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-167.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/25.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-168.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/250.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-169.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/251.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-170.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/252.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-171.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/253.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-172.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/254.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-173.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/255.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-174.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/256.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-175.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/257.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-176.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/258.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-177.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/259.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-178.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/26.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-179.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/260.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-180.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/261.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-181.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/262.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-182.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/263.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-183.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/264.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-184.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/265.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-185.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/266.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-186.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/267.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-187.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/268.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-188.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/269.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-189.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/27.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-190.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/270.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-191.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/271.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-192.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/272.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-193.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/273.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-194.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/274.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-195.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/275.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-196.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/276.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-197.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/277.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-198.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/278.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-199.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/279.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-200.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/28.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-201.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/280.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-202.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/281.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-203.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/282.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-204.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/283.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-205.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/284.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-206.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/285.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-207.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/286.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-208.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/287.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-209.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/288.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-210.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/289.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-211.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/29.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-212.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/290.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-213.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/291.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-214.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/292.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-215.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/293.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-216.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/294.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-217.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/295.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-218.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/296.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-219.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/297.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-220.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/298.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-221.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/299.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-222.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/3.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-223.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/30.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-224.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/300.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-225.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/301.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-226.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/302.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-227.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/303.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-228.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/304.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-229.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/305.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-230.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/306.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-231.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/307.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-232.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/308.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-233.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/309.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-234.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/31.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-235.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/310.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-236.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/311.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-237.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/312.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-238.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/313.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-239.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/314.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-240.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/315.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-241.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/316.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-242.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/317.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-243.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/318.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-244.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/319.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-245.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/32.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-246.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/320.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-247.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/321.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-248.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/322.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-249.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/323.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-250.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/324.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-251.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/325.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-252.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/326.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-253.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/327.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-254.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/evaluation/Bread/328.jpg a s3://landing-zone/temporal_landing/Bread-evaluation-255.jpg
# ...
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/380.jpg a s3://landing-zone/temporal_landing/Meat-validation-15185.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/381.jpg a s3://landing-zone/temporal_landing/Meat-validation-15186.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/382.jpg a s3://landing-zone/temporal_landing/Meat-validation-15187.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/383.jpg a s3://landing-zone/temporal_landing/Meat-validation-15188.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/384.jpg a s3://landing-zone/temporal_landing/Meat-validation-15189.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/385.jpg a s3://landing-zone/temporal_landing/Meat-validation-15190.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/386.jpg a s3://landing-zone/temporal_landing/Meat-validation-15191.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/387.jpg a s3://landing-zone/temporal_landing/Meat-validation-15192.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/388.jpg a s3://landing-zone/temporal_landing/Meat-validation-15193.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/389.jpg a s3://landing-zone/temporal_landing/Meat-validation-15194.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/39.jpg a s3://landing-zone/temporal_landing/Meat-validation-15195.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/390.jpg a s3://landing-zone/temporal_landing/Meat-validation-15196.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/391.jpg a s3://landing-zone/temporal_landing/Meat-validation-15197.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/392.jpg a s3://landing-zone/temporal_landing/Meat-validation-15198.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/393.jpg a s3://landing-zone/temporal_landing/Meat-validation-15199.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/394.jpg a s3://landing-zone/temporal_landing/Meat-validation-15200.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/395.jpg a s3://landing-zone/temporal_landing/Meat-validation-15201.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/396.jpg a s3://landing-zone/temporal_landing/Meat-validation-15202.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/397.jpg a s3://landing-zone/temporal_landing/Meat-validation-15203.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/398.jpg a s3://landing-zone/temporal_landing/Meat-validation-15204.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/399.jpg a s3://landing-zone/temporal_landing/Meat-validation-15205.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/4.jpg a s3://landing-zone/temporal_landing/Meat-validation-15206.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/40.jpg a s3://landing-zone/temporal_landing/Meat-validation-15207.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/400.jpg a s3://landing-zone/temporal_landing/Meat-validation-15208.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/401.jpg a s3://landing-zone/temporal_landing/Meat-validation-15209.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/402.jpg a s3://landing-zone/temporal_landing/Meat-validation-15210.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/403.jpg a s3://landing-zone/temporal_landing/Meat-validation-15211.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/404.jpg a s3://landing-zone/temporal_landing/Meat-validation-15212.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/405.jpg a s3://landing-zone/temporal_landing/Meat-validation-15213.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/406.jpg a s3://landing-zone/temporal_landing/Meat-validation-15214.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/407.jpg a s3://landing-zone/temporal_landing/Meat-validation-15215.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/408.jpg a s3://landing-zone/temporal_landing/Meat-validation-15216.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/409.jpg a s3://landing-zone/temporal_landing/Meat-validation-15217.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/41.jpg a s3://landing-zone/temporal_landing/Meat-validation-15218.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/410.jpg a s3://landing-zone/temporal_landing/Meat-validation-15219.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/411.jpg a s3://landing-zone/temporal_landing/Meat-validation-15220.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/412.jpg a s3://landing-zone/temporal_landing/Meat-validation-15221.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/413.jpg a s3://landing-zone/temporal_landing/Meat-validation-15222.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/414.jpg a s3://landing-zone/temporal_landing/Meat-validation-15223.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/415.jpg a s3://landing-zone/temporal_landing/Meat-validation-15224.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/416.jpg a s3://landing-zone/temporal_landing/Meat-validation-15225.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/417.jpg a s3://landing-zone/temporal_landing/Meat-validation-15226.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/418.jpg a s3://landing-zone/temporal_landing/Meat-validation-15227.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/419.jpg a s3://landing-zone/temporal_landing/Meat-validation-15228.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/42.jpg a s3://landing-zone/temporal_landing/Meat-validation-15229.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/420.jpg a s3://landing-zone/temporal_landing/Meat-validation-15230.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/421.jpg a s3://landing-zone/temporal_landing/Meat-validation-15231.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/422.jpg a s3://landing-zone/temporal_landing/Meat-validation-15232.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/423.jpg a s3://landing-zone/temporal_landing/Meat-validation-15233.jpg
# [OK] Subido /home/paloli/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1/validation/Meat/424.jpg a s3://landing-zone/temporal_landing/Meat-validation-15234.jpg
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/src/data_management/data_ingestion/image_ingestion.py", line 93, in <module>
#     main()
#     ~~~~^^
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/src/data_management/data_ingestion/image_ingestion.py", line 81, in main
#     uploaded = upload_directory_images(client, bucket, folder, dataset_path)
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/src/data_management/data_ingestion/image_ingestion.py", line 59, in upload_directory_images
#     upload_file_to_bucket(client, bucket, object_name, img_file, img_type)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/src/data_management/data_ingestion/image_ingestion.py", line 30, in upload_file_to_bucket
#     client.fput_object(
#     ~~~~~~~~~~~~~~~~~~^
#         bucket,
#         ^^^^^^^
#     ...<3 lines>...
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/minio/api.py", line 1054, in fput_object
#     return self.put_object(
#            ~~~~~~~~~~~~~~~^
#         bucket_name,
#         ^^^^^^^^^^^^
#     ...<11 lines>...
#         legal_hold=legal_hold,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/minio/api.py", line 1955, in put_object
#     return self._put_object(
#            ~~~~~~~~~~~~~~~~^
#         bucket_name, object_name, part_data, headers,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/minio/api.py", line 1784, in _put_object
#     response = self._execute(
#         "PUT",
#     ...<5 lines>...
#         no_body_trace=True,
#     )
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/minio/api.py", line 444, in _execute
#     return self._url_open(
#            ~~~~~~~~~~~~~~^
#         method,
#         ^^^^^^^
#     ...<7 lines>...
#         no_body_trace=no_body_trace,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/minio/api.py", line 306, in _url_open
#     response = self._http.urlopen(
#         method,
#     ...<3 lines>...
#         preload_content=preload_content,
#     )
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/urllib3/poolmanager.py", line 443, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#         conn,
#     ...<10 lines>...
#         **response_kw,
#     )
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#   File "/home/paloli/Documentos/MDS/ADSDB/ADSDB-Project/.venv/lib/python3.13/site-packages/urllib3/connection.py", line 516, in getresponse
#     httplib_response = super().getresponse()
#   File "/usr/lib/python3.13/http/client.py", line 1430, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 8
#       6 for step in MODULES:
#       7     print(f"\n=== Step: {step['name']} ===")
# ----> 8     run_module(
#       9         module = step["module"],
#      10         args = step.get("args", []),
#      11         check = True,
#      12         timeout = None
#      13     )
#      14 print("\n=== Pipeline completed successfully ===")
#
# Cell In[15], line 17, in run_module(module, args, env, check, timeout, cwd)
#      14 if env: env2.update(env)
#      16 start = time.time()
# ---> 17 rc = subprocess.run(cmd, env=env2, cwd=cwd, check=False, timeout=timeout).returncode
#      18 if check and rc != 0:
#      19     raise subprocess.CalledProcessError(rc, cmd)
#
# File /usr/lib/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File /usr/lib/python3.13/subprocess.py:1214, in Popen.communicate(self, input, timeout)
#    1212         stderr = self.stderr.read()
#    1213         self.stderr.close()
# -> 1214     self.wait()
#    1215 else:
#    1216     if timeout is not None:
#
# File /usr/lib/python3.13/subprocess.py:1280, in Popen.wait(self, timeout)
#    1278     endtime = _time() + timeout
#    1279 try:
# -> 1280     return self._wait(timeout=timeout)
#    1281 except KeyboardInterrupt:
#    1282     # https://bugs.python.org/issue25942
#    1283     # The first keyboard interrupt waits briefly for the child to
#    1284     # exit under the common assumption that it also received the ^C
#    1285     # generated SIGINT and will exit rapidly.
#    1286     if timeout is not None:
#
# File /usr/lib/python3.13/subprocess.py:2066, in Popen._wait(self, timeout)
#    2064 if self.returncode is not None:
#    2065     break  # Another thread waited.
# -> 2066 (pid, sts) = self._try_wait(0)
#    2067 # Check the pid and loop as waitpid has been known to
#    2068 # return 0 even without WNOHANG in odd situations.
#    2069 # http://bugs.python.org/issue14396.
#    2070 if pid == self.pid:
#
# File /usr/lib/python3.13/subprocess.py:2024, in Popen._try_wait(self, wait_flags)
#    2022 """All callers to this function MUST hold self._waitpid_lock."""
#    2023 try:
# -> 2024     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2025 except ChildProcessError:
#    2026     # This happens if SIGCLD is set to be ignored or waiting
#    2027     # for child processes has otherwise been disabled for our
#    2028     # process.  This child is dead, we can't get the status.
#    2029     pid = self.pid
#
# KeyboardInterrupt:
